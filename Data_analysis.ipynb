# %% [markdown]
# # Data analisys
#
# Before developing regression models, analysing our data may reveal important information. With the acquired knowledge, we may be able to detect problems and quirks in our data, and deal with them properly.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Library loading

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Data loading

# %%
df = pd.read_parquet("data/windsat_2017")

# %% [markdown]
# ## Basic structure
#
# Let's validate the dataset before any advanced analysis.

# %% [markdown]
# ### Shape

# %%
df.shape
# Out:
# (13225757, 48)

# %% [markdown]
# We can see we have a very substantial amount of data.

# %% [markdown]
# ### Variables

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13225757 entries, 0 to 13225756
# Data columns (total 48 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   latitude_grid                float32
#  1   longitude_grid               float32
#  2   surtep_ERA5                  float32
#  3   fwns                         float32
#  4   Tmn                          float32
#  5   PWV                          float32
#  6   VOD                          float32
#  7   vsm                          float32
#  8   VPD                          float32
#  9   ref_land_emis_de_lannoy_K_h  float64
#  10  ref_land_emis_de_lannoy_K_v  float64
#  11  tbtoa19V                     float32
#  12  tbtoa19H                     float32
#  13  tbtoa37V                     float32
#  14  tbtoa37H                     float32
#  15  tran19V                      float32
#  16  tran19H                      float32
#  17  tran37V                      float32
#  18  tran37H                      float32
#  19  tbdw19V                      float32
#  20  tbdw19H                      float32
#  21  tbdw37V                      float32
#  22  tbdw37H                      float32
#  23  tbup19V                      float32
#  24  tbup19H                      float32
#  25  tbup37V                      float32
#  26  tbup37H                      float32
#  27  tbboa_1st_order19V           float32
#  28  tbboa_1st_order19H           float32
#  29  tbboa_1st_order37V           float32
#  30  tbboa_1st_order37H           float32
#  31  tbboa_de_lannoy19V           float32
#  32  tbboa_de_lannoy19H           float32
#  33  tbboa_de_lannoy37V           float32
#  34  tbboa_de_lannoy37H           float32
#  35  emiss19H_de_lannoy           float32
#  36  emiss19V_de_lannoy           float32
#  37  emiss37H_de_lannoy           float32
#  38  emiss37V_de_lannoy           float32
#  39  denominator                  float64
#  40  term_1                       float64
#  41  term_2                       float64
#  42  fwns_calculated              float64
#  43  clase                        float64
#  44  porcentaje clase             float64
#  45  sm_bin                       int64
#  46  vod_bin                      int64
#  47  day                          int64
# dtypes: float32(37), float64(8), int64(3)
# memory usage: 2.9 GB

# %% [markdown]
# There are a lot of variables in the dataset. It is possible not all of these are essential to our project.

# %% [markdown]
# ### Simple statistics

# %%
df.describe(include="all")
# Out:
#        latitude_grid  longitude_grid   surtep_ERA5          fwns  \
# count   1.322576e+07    1.322576e+07  1.322576e+07  1.322576e+07
# mean    3.603915e+01    1.401255e+02  2.858118e+02  4.164822e-02
# std     3.157395e+01    1.003987e+02  2.341554e+01  7.066451e-02
# min    -5.587500e+01    1.250000e-01  2.396749e+02  0.000000e+00
# 25%     1.837500e+01    5.412500e+01  2.793567e+02  0.000000e+00
# 50%     4.737500e+01    1.136250e+02  2.861123e+02  1.280200e-02
# 75%     6.162500e+01    2.421250e+02  2.925476e+02  4.747691e-02
# max     8.237500e+01    3.598750e+02  3.131768e+02  8.460522e-01
#
#                 Tmn           PWV           VOD           vsm           VPD  \
# count  1.322576e+07  1.322576e+07  1.322576e+07  1.322576e+07  1.322576e+07
# mean   2.824166e+02  1.946441e+01  3.971513e-01  1.904094e-01  5.689056e-01
# std    2.109371e+01  1.113898e+01  1.824952e-01  9.200675e-02  7.547768e-01
# min    2.602157e+02  0.000000e+00  0.000000e+00  2.500000e-02  0.000000e+00
# 25%    2.752077e+02  1.194889e+01  2.640085e-01  1.248152e-01  2.826200e-02
# 50%    2.811289e+02  1.728142e+01  3.935674e-01  2.031098e-01  2.677113e-01
# 75%    2.900103e+02  2.413174e+01  5.313323e-01  2.538548e-01  8.357491e-01
# max    3.111082e+02  8.000000e+01  9.985774e-01  6.000000e-01  6.695256e+00
#
#        ref_land_emis_de_lannoy_K_h  ...  emiss37V_de_lannoy   denominator  \
# count                 1.322576e+07  ...        1.322576e+07  1.322576e+07
# mean                  9.049120e-01  ...        9.375858e-01  1.498645e+00
# std                   3.604884e-02  ...        6.724536e-02  1.630431e-02
# min                   7.615927e-01  ...        5.567881e-01  1.418582e+00
# 25%                   8.899351e-01  ...        9.271837e-01  1.493521e+00
# 50%                   9.161988e-01  ...        9.489298e-01  1.496426e+00
# 75%                   9.329485e-01  ...        9.623111e-01  1.500800e+00
# max                   9.457885e-01  ...        1.166487e+00  1.684472e+00
#
#              term_1        term_2  fwns_calculated         clase  \
# count  1.322576e+07  1.322576e+07     1.322576e+07  1.322576e+07
# mean   1.355949e+00  1.305607e+00     5.034241e-02  9.369298e+00
# std    5.109201e-02  1.147912e-01     9.794633e-02  1.134503e+01
# min    1.145924e+00  4.555947e-01    -4.840022e-01  0.000000e+00
# 25%    1.337573e+00  1.254467e+00    -5.330032e-03  0.000000e+00
# 50%    1.368915e+00  1.337943e+00     1.924895e-02  0.000000e+00
# 75%    1.387827e+00  1.384879e+00     7.166362e-02  2.200000e+01
# max    1.434450e+00  1.809225e+00     8.367879e-01  3.300000e+01
#
#        porcentaje clase        sm_bin       vod_bin           day
# count      1.322576e+07  1.322576e+07  1.322576e+07  1.322576e+07
# mean       1.659104e+01  1.386219e+00  6.107769e+00  1.973433e+02
# std        2.310372e+01  9.368460e-01  2.373384e+00  8.172960e+01
# min        0.000000e+00 -1.000000e+00  0.000000e+00  1.000000e+00
# 25%        0.000000e+00  1.000000e+00  5.000000e+00  1.490000e+02
# 50%        6.000000e+00  2.000000e+00  6.000000e+00  2.010000e+02
# 75%        2.400000e+01  2.000000e+00  8.000000e+00  2.570000e+02
# max        1.000000e+02  4.000000e+00  1.000000e+01  3.650000e+02
#
# [8 rows x 48 columns]

# %% [markdown]
# Although we'll later visualize this data in a much better way, this helps us validate the data.

# %% [markdown]
# ### Missing values

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# latitude_grid                  0.0
# longitude_grid                 0.0
# tbup37H                        0.0
# tbboa_1st_order19V             0.0
# tbboa_1st_order19H             0.0
# tbboa_1st_order37V             0.0
# tbboa_1st_order37H             0.0
# tbboa_de_lannoy19V             0.0
# tbboa_de_lannoy19H             0.0
# tbboa_de_lannoy37V             0.0
# tbboa_de_lannoy37H             0.0
# emiss19H_de_lannoy             0.0
# emiss19V_de_lannoy             0.0
# emiss37H_de_lannoy             0.0
# emiss37V_de_lannoy             0.0
# denominator                    0.0
# term_1                         0.0
# term_2                         0.0
# fwns_calculated                0.0
# clase                          0.0
# porcentaje clase               0.0
# sm_bin                         0.0
# vod_bin                        0.0
# tbup37V                        0.0
# tbup19H                        0.0
# tbup19V                        0.0
# tbtoa19V                       0.0
# surtep_ERA5                    0.0
# fwns                           0.0
# Tmn                            0.0
# PWV                            0.0
# VOD                            0.0
# vsm                            0.0
# VPD                            0.0
# ref_land_emis_de_lannoy_K_h    0.0
# ref_land_emis_de_lannoy_K_v    0.0
# tbtoa19H                       0.0
# tbdw37H                        0.0
# tbtoa37V                       0.0
# tbtoa37H                       0.0
# tran19V                        0.0
# tran19H                        0.0
# tran37V                        0.0
# tran37H                        0.0
# tbdw19V                        0.0
# tbdw19H                        0.0
# tbdw37V                        0.0
# day                            0.0
# dtype: float64

# %% [markdown]
# Thankfully, we managed the data preprocessing well enough so that we don't have to deal with missing data now.

# %% [markdown]
# ## Univariate statistical analysis
#
# We will now check the individual structure of most variables through histograms.

# %% [markdown]
# ### LPDR variables

# %%
df_lpdr = df[['fwns', 'Tmn', 'PWV', 'VOD', 'vsm', 'VPD']]
df_lpdr.hist(bins=30, figsize=(12, 12))
plt.tight_layout()
plt.show()

# %% [markdown]
# We now know the distribution of our target variable, `fwns`. We see it is biased towards zero, with a decaying trend after that. Maybe a transformation would be in order.

# %% [markdown]
# ### WINDSAT variables
#
# We'll only visualize the 19V variables since most of the frequencies and polarizations follow similar distributions.

# %%
df_windsat = df[['tbtoa19V', 'tran19V', 'tbdw19V', 'tbup19V']]
df_windsat.hist(bins=30, figsize=(12, 8))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Other variables

# %%
df_other = df[['surtep_ERA5', 'emiss19V_de_lannoy', 'ref_land_emis_de_lannoy_K_h', 'ref_land_emis_de_lannoy_K_v', 'fwns_calculated']]
df_other.hist(bins=30, figsize=(12, 12))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Multivariate analysis
#
# With as many as 47 variables in a dataset, it is imperative that we study their relation. With some luck, we may be able to remove a decent amount of them, speeding the training process.

# %% [markdown]
# ### Correlation matrix

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(16, 16))

ax = sns.heatmap(
    corr,
    cmap="coolwarm",
    vmin=-1,
    vmax=1,
    center=0,
    square=True,
    cbar=False
)

# Force all ticks
ax.set_xticks(np.arange(len(corr.columns)) + 0.5)
ax.set_yticks(np.arange(len(corr.columns)) + 0.5)

ax.set_xticklabels(corr.columns, rotation=90, fontsize=6)
ax.set_yticklabels(corr.columns, rotation=0, fontsize=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# There are clearly many related variables, but those existing between `tran`, `tbdw` and `tbup` are telling.

# %% [markdown]
# ### Target correlation

# %%
corr['fwns'].sort_values(ascending=False)
# Out:
# fwns                           1.000000
# fwns_calculated                0.855435
# denominator                    0.531121
# vsm                            0.463293
# porcentaje clase               0.379586
# sm_bin                         0.346232
# tbup19V                        0.262974
# tbup19H                        0.262974
# tbdw19V                        0.262965
# tbdw19H                        0.262965
# tbup37H                        0.245943
# tbup37V                        0.245943
# tbdw37H                        0.245924
# tbdw37V                        0.245924
# PWV                            0.211043
# clase                          0.163359
# longitude_grid                 0.132156
# surtep_ERA5                    0.086078
# latitude_grid                  0.064189
# day                            0.005567
# Tmn                           -0.065733
# term_1                        -0.113530
# vod_bin                       -0.135155
# VOD                           -0.182565
# VPD                           -0.228216
# ref_land_emis_de_lannoy_K_h   -0.242474
# tran37V                       -0.244691
# tran37H                       -0.244691
# tran19H                       -0.255234
# tran19V                       -0.255234
# ref_land_emis_de_lannoy_K_v   -0.538154
# tbtoa37V                      -0.694444
# tbboa_1st_order37V            -0.701230
# tbtoa19V                      -0.707397
# tbboa_de_lannoy37V            -0.709018
# tbboa_1st_order19V            -0.711557
# tbboa_de_lannoy19V            -0.716058
# tbtoa37H                      -0.726324
# tbboa_1st_order37H            -0.731305
# tbboa_de_lannoy37H            -0.737209
# tbtoa19H                      -0.751122
# tbboa_1st_order19H            -0.753595
# tbboa_de_lannoy19H            -0.756492
# term_2                        -0.780436
# emiss37H_de_lannoy            -0.793041
# emiss19H_de_lannoy            -0.799950
# emiss19V_de_lannoy            -0.853042
# emiss37V_de_lannoy            -0.857484
# Name: fwns, dtype: float64

# %% [markdown]
# As was to be expected, the `fwns` estimated through the physical formula is the most correlated variable, but some others also reveal close ties.

# %% [markdown]
# ## Machine learning oriented analysis
#
# Let's check specific points in the structure of the dataset that could tell us better ways of training models.

# %% [markdown]
# ### Scaling needs

# %%
df.max() - df.min()
# Out:
# latitude_grid                  138.250000
# longitude_grid                 359.750000
# surtep_ERA5                     73.501892
# fwns                             0.846052
# Tmn                             50.892456
# PWV                             80.000000
# VOD                              0.998577
# vsm                              0.575000
# VPD                              6.695256
# ref_land_emis_de_lannoy_K_h      0.184196
# ref_land_emis_de_lannoy_K_v      0.111272
# tbtoa19V                       168.279999
# tbtoa19H                       238.077515
# tbtoa37V                       163.837479
# tbtoa37H                       231.187500
# tran19V                          0.084570
# tran19H                          0.084570
# tran37V                          0.171619
# tran37H                          0.171619
# tbdw19V                         22.487835
# tbdw19H                         22.487835
# tbdw37V                         45.597780
# tbdw37H                         45.597780
# tbup19V                         22.409249
# tbup19H                         22.409249
# tbup37V                         45.298647
# tbup37H                         45.298647
# tbboa_1st_order19V             170.912247
# tbboa_1st_order19H             242.300491
# tbboa_1st_order37V             167.257416
# tbboa_1st_order37H             236.281113
# tbboa_de_lannoy19V             173.665894
# tbboa_de_lannoy19H             247.207138
# tbboa_de_lannoy37V             170.419083
# tbboa_de_lannoy37H             240.924362
# emiss19H_de_lannoy               0.898349
# emiss19V_de_lannoy               0.614850
# emiss37H_de_lannoy               0.890973
# emiss37V_de_lannoy               0.609699
# denominator                      0.265890
# term_1                           0.288526
# term_2                           1.353631
# fwns_calculated                  1.320790
# clase                           33.000000
# porcentaje clase               100.000000
# sm_bin                           5.000000
# vod_bin                         10.000000
# day                            364.000000
# dtype: float64

# %% [markdown]
# We can see that even though `fwns` has really small consistent values, other ones like surtep_ERA5 or tbtoa have extremely large values. We may need to scale this features down or outright remove them to improve our training.

# %% [markdown]
# ### Dimensionality study

# %%
numeric_df = df.select_dtypes(include='number')

scaler = StandardScaler()
X_scaled = scaler.fit_transform(numeric_df)

# %%
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# %%
explained = pca.explained_variance_ratio_
cumulative = np.cumsum(explained)

plt.figure(figsize=(8,5))
plt.plot(cumulative, marker='o')
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.grid(True)
plt.show()

# %%
loadings = pd.DataFrame(
    pca.components_.T,
    columns=[f'PC{i+1}' for i in range(len(numeric_df.columns))],
    index=numeric_df.columns
)

loadings[['PC1','PC2','PC3']].sort_values('PC1', ascending=False)
# Out:
#                                   PC1       PC2       PC3
# emiss19V_de_lannoy           0.207997  0.012028  0.041154
# emiss37V_de_lannoy           0.207120  0.021070  0.017265
# tbboa_de_lannoy19V           0.206846  0.050155  0.138650
# tbboa_de_lannoy37V           0.206688  0.061800  0.127242
# tbboa_1st_order19V           0.206099  0.051522  0.140539
# tbtoa19V                     0.205515  0.052198  0.142338
# tbboa_1st_order37V           0.205285  0.064626  0.130503
# tbtoa37V                     0.204276  0.066059  0.133450
# tbboa_de_lannoy37H           0.198629  0.123371 -0.068199
# tbboa_de_lannoy19H           0.198516  0.122620 -0.086420
# tbboa_1st_order19H           0.197993  0.124260 -0.085000
# tbtoa19H                     0.197645  0.125468 -0.083572
# tbboa_1st_order37H           0.197513  0.126575 -0.065554
# tbtoa37H                     0.196751  0.128846 -0.063065
# emiss19H_de_lannoy           0.188277  0.098902 -0.155965
# emiss37H_de_lannoy           0.187813  0.096404 -0.149942
# term_2                       0.183752  0.100179 -0.159416
# ref_land_emis_de_lannoy_K_v  0.122409  0.028422 -0.023540
# tran19H                      0.120478 -0.231080 -0.037955
# tran19V                      0.120478 -0.231080 -0.037955
# tran37H                      0.100784 -0.248840 -0.073672
# tran37V                      0.100784 -0.248840 -0.073672
# VPD                          0.097053 -0.053875  0.299820
# Tmn                          0.086734  0.055043  0.277728
# ref_land_emis_de_lannoy_K_h  0.051816  0.146149 -0.271544
# surtep_ERA5                  0.046628  0.080986  0.208114
# VOD                          0.039001  0.157596 -0.254161
# vod_bin                      0.025019  0.155556 -0.280733
# term_1                       0.022286  0.146847 -0.279982
# PWV                         -0.011286  0.152219  0.177841
# day                         -0.012890  0.002778 -0.052667
# longitude_grid              -0.030135  0.017064 -0.045675
# latitude_grid               -0.061037 -0.018961 -0.179499
# clase                       -0.080457  0.044634 -0.161770
# tbdw37H                     -0.093808  0.250903  0.092338
# tbdw37V                     -0.093808  0.250903  0.092338
# tbup37H                     -0.093827  0.250902  0.092280
# tbup37V                     -0.093827  0.250902  0.092280
# sm_bin                      -0.106222  0.061062 -0.226782
# tbdw19H                     -0.111831  0.240333  0.070316
# tbdw19V                     -0.111831  0.240333  0.070316
# tbup19V                     -0.111854  0.240324  0.070236
# tbup19H                     -0.111854  0.240324  0.070236
# denominator                 -0.120263 -0.027965  0.022963
# porcentaje clase            -0.120759  0.009382 -0.050048
# vsm                         -0.127063  0.063074 -0.232349
# fwns                        -0.192403 -0.034461  0.043928
# fwns_calculated             -0.203729 -0.040807  0.040785

# %%
plt.figure(figsize=(10,6))
loadings['PC1'].sort_values().plot(kind='barh')
plt.title("PC1 Loadings")
plt.show()

# %%
plt.figure(figsize=(7,7))

for i, var in enumerate(numeric_df.columns):
    plt.arrow(0, 0, 
              loadings.iloc[i,0], 
              loadings.iloc[i,1],
              alpha=0.7)
    plt.text(loadings.iloc[i,0]*1.1, 
             loadings.iloc[i,1]*1.1, 
             var, fontsize=8)

plt.axhline(0)
plt.axvline(0)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Correlation Circle")
plt.grid()
plt.show()
